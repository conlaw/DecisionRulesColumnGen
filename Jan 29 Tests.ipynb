# %%
import pandas as pd
from test_helpers import *

# %%
results = []
datasets = ['adult','compas','default']
protected_features = {'compas': 'race', 
                      'adult': 'gender',
                      'default': 'X2'
                     }
fair_met = 'EqOfOp'
test_params = {
            'price_limit': 45,
            'train_limit': 300,
            'fixed_model_params': {
                'ruleGenerator': 'Hybrid',
                'masterSolver':'barrierCrossover',
                'numRulesToReturn': 100,
                'fairness_module': 'EqOfOp'
            },
        }

eps_range = {'adult': [0, 0.01, 0.05, 0.1, 1],
    'compas':[0, 0.01, 0.05, 0.1, 0.15, 0.2, 1],
     'default': [0, 0.01, 0.05, 0.1, 1]
    }
C_range = {'adult': [40, 5, 15, 30],
    'compas': [5, 10, 20, 30],
     'default': [5, 10, 20, 30]
    }
epsilons = [0, 0.01, 0.05, 0.1, 0.5, 1]
test_complex = [10, 15, 20]

for i in range(10):
    print('***** FOLD %d ******'%i)

    for dataset in datasets:
        print('**** DATASET %s ******'%dataset)
        group_var = protected_features[dataset]
        name = dataset+'_'+str(fair_met)

        train  = pd.read_csv('data_split/bin_'+dataset+'_train_%d.csv'%i)
        test = pd.read_csv('data_split/bin_'+dataset+'_test_%d.csv'%i)
        
        isFirst = True
        for ruleset in ['faircgEqOp','faircgEqOd','rf','dt']:
            print('***** Ruleset %s ******'%ruleset)
            new_rules = np.load('rules/'+ruleset+'_%s_fold_%d.npy'%(dataset, i)).astype(int)
            if isFirst:
                saved_rules = new_rules
                isFirst = False
            else:
                saved_rules = np.concatenate([saved_rules,new_rules])

        for eps in eps_range[dataset]:
            for C in C_range[dataset]:
                res = TestResults(name+' '+'(%d,%d)_final'%(eps, C)+'-'+str(i))
                res.res['eps'] = eps
                res.res['C'] = C

                test_params = test_params.copy()
                test_params['fixed_model_params']['epsilon'] = eps
                test_params['fixed_model_params']['ruleComplexity'] = C
                
                print(test_params)
                res, classif = runSingleTest(train.drop('Y',axis=1).to_numpy(), train['Y'].to_numpy(), 
                                             train[group_var].to_numpy(), 
                                             test.drop('Y',axis=1).to_numpy(), test['Y'].to_numpy(), 
                                             test[group_var].to_numpy(), 
                                             test_params, 
                                             saved_rules, res, colGen = True, rule_filter = True)
                
                rules = classif.ruleMod.rules
                saved_rules = updateRuleSet(saved_rules,rules)
        np.save('rules/'+name+'_fold_'+str(i)+'_rules_final', saved_rules)
# Out:
# ***** FOLD 0 ******
# **** DATASET compas ******
# ***** Ruleset rf ******
# ***** Ruleset dt ******
# {'price_limit': 45, 'train_limit': 300, 'fixed_model_params': {'ruleGenerator': 'Hybrid', 'masterSolver': 'barrierCrossover', 'numRulesToReturn': 100, 'fairness_module': 'EqOfOp', 'epsilon': 0, 'ruleComplexity': 5}}
# Using Hybrid
#
# --------------------------------------------
# Warning: your license will expire in 6 days
# --------------------------------------------
#
# Using license file /Users/connorlawless/gurobi.lic
# Academic license - for non-commercial use only
# Using barrier with default crossover
# Changed value of parameter Method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Adding Rules
# Solving relaxed (filter) master
# Solving with 2306 rules
# Master solving took 0.15 seconds
# Computing reduced costs
# RC took 0.01 seconds
# Sorting RC and reset
# Length of reduced rule set:  1000
# resetting ruleMod
# resetting master
# Using barrier with default crossover
# Changed value of parameter Method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# init model
# adding rules
# done
# Sorting RC/reset took 1.24 seconds
# Time limit for column generation exceeded. Solving MIP.
# Solving relaxed (filter) master
# Solving with 1070 rules
# Master solving took 0.13 seconds
# Computing reduced costs
# RC took 0.01 seconds
# Sorting RC and reset
# Length of reduced rule set:  1000
# resetting ruleMod
# resetting master
# Using barrier with default crossover
# Changed value of parameter Method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# init model
# adding rules
# done
# Sorting RC/reset took 1.18 seconds
# Solving master IP
# Changed value of parameter TimeLimit to 300.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Master solving took 0.09 seconds
# Results: (Acc) 0.523 (Time) 306 (Complex) 0 (Cols Gen) 1000  (Num Iter) 1181
# {'accuracy': [0.5227272727272727], 'accuracy_train': [0.5303157894736842], 'mip': [[1763.5301909118753, 1763.5301909118523, 1763.5301909118753, 1750.6003044830675, 1750.6003044830677, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.6003044830675, 1750.60030448306 ...
# {'price_limit': 45, 'train_limit': 300, 'fixed_model_params': {'ruleGenerator': 'Hybrid', 'masterSolver': 'barrierCrossover', 'numRulesToReturn': 100, 'fairness_module': 'EqOfOp', 'epsilon': 0, 'ruleComplexity': 10, 'group': array([False,  True,  True, ..., False, False, False])}}
# Using Hybrid
# Using barrier with default crossover
# Changed value of parameter Method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Adding Rules
# /Users/connorlawless/opt/anaconda3/envs/CourseSchedule/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/connorlawless/opt/anaconda3/envs/CourseSchedule/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/connorlawless/opt/anaconda3/envs/CourseSchedule/lib/python3.7/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/connorlawless/opt/anaconda3/envs/CourseSchedule/lib/python3.7/site-packages/numpy/core/_methods.py:195: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/connorlawless/opt/anaconda3/envs/CourseSchedule/lib/python3.7/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Solving relaxed (filter) master
# Solving with 2375 rules
# Master solving took 0.17 seconds
# Computing reduced costs
# RC took 0.01 seconds
# Sorting RC and reset
# Length of reduced rule set:  1000
# resetting ruleMod
# resetting master
# Using barrier with default crossover
# Changed value of parameter Method to 2
#    Prev: -1  Min: -1  Max: 5  Default: -1
# init model
# adding rules
# done
# Sorting RC/reset took 1.18 seconds
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-f5bba5d82c40> in <module>
#      65                                              test[group_var].to_numpy(),
#      66                                              test_params,
# ---> 67                                              saved_rules, res, colGen = True, rule_filter = True)
#      68
#      69                 rules = classif.ruleMod.rules
#
# ~/Documents/DecisionRulesColumnGen/test_helpers.py in runSingleTest(X_tr, Y_tr, g_tr, X_t, Y_t, g_t, test_params, rules, res, colGen, rule_filter)
#     246                 timeLimitPricing = test_params['price_limit'],
#     247                 colGen = colGen,
# --> 248                 rule_filter = rule_filter)
#     249     time_to_exec = time.perf_counter() - start_time
#     250
#
# ~/Documents/DecisionRulesColumnGen/Classifier.py in fit(self, initial_rules, verbose, timeLimit, timeLimitPricing, colGen, rule_filter)
#      67             #print('Solving Master')
#      68             master_solve = time.perf_counter()
# ---> 69             results = self.master.solve(verbose = verbose, relax = True)
#      70
#      71             #self.master.model.write('master_model.lp')
#
# ~/Documents/DecisionRulesColumnGen/master_model/CompactDoubleSidedMaster.py in solve(self, relax, verbose, saveModel)
#      99         results['model'] = self.finalMod
#     100         results['obj'] = self.finalMod.objVal
# --> 101         results['ruleSet'] = self.getRuleSet(self.finalMod.getVars())
#     102
#     103         if relax:
#
# ~/Documents/DecisionRulesColumnGen/master_model/CompactDoubleSidedMaster.py in getRuleSet(self, decisionVars)
#     189
#     190         # For rules generated during relaxed version, incldues all rules where w > 0
# --> 191         inclRules = [v.x > 0 for v in decisionVars[len(self.x)::]]
#     192
#     193         # Return what we can given the current state of variables
#
# ~/Documents/DecisionRulesColumnGen/master_model/CompactDoubleSidedMaster.py in <listcomp>(.0)
#     189
#     190         # For rules generated during relaxed version, incldues all rules where w > 0
# --> 191         inclRules = [v.x > 0 for v in decisionVars[len(self.x)::]]
#     192
#     193         # Return what we can given the current state of variables
#
# var.pxi in gurobipy.Var.__getattr__()
#
# var.pxi in gurobipy.Var.getAttr()
#
# attrutil.pxi in gurobipy.__getattr()
#
# AttributeError: Unable to retrieve attribute 'x'

# %%
results = []
datasets = ['adult','compas','default']
protected_features = {'compas': 'race', 
                      'adult': 'gender',
                      'default': 'X2'
                     }
fair_met = 'EqOfOp'
test_params = {
            'price_limit': 45,
            'train_limit': 300,
            'fixed_model_params': {
                'ruleGenerator': 'Hybrid',
                'masterSolver':'barrierCrossover',
                'numRulesToReturn': 100,
                'fairness_module': 'HammingEqOdd'
            },
        }

eps_range = {'adult': [0, 0.01, 0.05, 0.1, 1],
    'compas':[0, 0.01, 0.05, 0.1, 0.15, 0.2, 1],
     'default': [0, 0.01, 0.05, 0.1, 1]
    }
C_range = {'adult': [40, 5, 15, 30],
    'compas': [5, 10, 20, 30],
     'default': [5, 10, 20, 30]
    }
epsilons = [0, 0.01, 0.05, 0.1, 0.5, 1]
test_complex = [10, 15, 20]

for i in range(10):
    print('***** FOLD %d ******'%i)

    for dataset in datasets:
        print('**** DATASET %s ******'%dataset)
        group_var = protected_features[dataset]
        name = dataset+'_'+str(fair_met)

        train  = pd.read_csv('data_split/bin_'+dataset+'_train_%d.csv'%i)
        test = pd.read_csv('data_split/bin_'+dataset+'_test_%d.csv'%i)
        
        isFirst = True
        for ruleset in ['faircgEqOp','faircgEqOd','rf','dt']:
            print('***** Ruleset %s ******'%ruleset)
            new_rules = np.load('rules/'+ruleset+'_%s_fold_%d.npy'%(dataset, i)).astype(int)
            if isFirst:
                saved_rules = new_rules
                isFirst = False
            else:
                saved_rules = np.concatenate([saved_rules,new_rules])

        for eps in eps_range[dataset]:
            for C in C_range[dataset]:
                res = TestResults(name+' '+'(%d,%d)_final'%(eps, C)+'-'+str(i))
                res.res['eps'] = eps*2
                res.res['C'] = C

                test_params = test_params.copy()
                test_params['fixed_model_params']['epsilon'] = eps*2
                test_params['fixed_model_params']['ruleComplexity'] = C
                
                print(test_params)
                res, classif = runSingleTest(train.drop('Y',axis=1).to_numpy(), train['Y'].to_numpy(), 
                                             train[group_var].to_numpy(), 
                                             test.drop('Y',axis=1).to_numpy(), test['Y'].to_numpy(), 
                                             test[group_var].to_numpy(), 
                                             test_params, 
                                             saved_rules, res, colGen = True, rule_filter = True)
                
                rules = classif.ruleMod.rules
                saved_rules = updateRuleSet(saved_rules,rules)
        np.save('rules/'+name+'_fold_'+str(i)+'_rules_final', saved_rules)
