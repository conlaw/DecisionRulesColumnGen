# %%
from test_helpers2 import run_test
import pandas as pd

# %%
data = pd.read_csv('data/german_male.csv')

data.shape
# Out:
# (310, 23)

# %%
68/310
# Out:
# 0.21935483870967742

# %%
data = pd.read_csv('data/german_female.csv')

data.shape
# Out:
# (690, 23)

# %%
138/690
# Out:
# 0.2

# %%
#Epsilon = 2%
#Accuracy for female is 72%, for male is 68%

# %%
dataInfo = {
    'file': 'data/german_male.csv',
    'groupCol': 'gender'
}

globalArgs = {
    'num_splits': 5,
}

test_params = [{
    'data': 'data/german_male.csv',
    'price_limit': 45,
    'train_limit': 300,
    'fixed_model_params': {
        'ruleGenerator': 'DNF_IP',
        'numRulesToReturn': 100,
        'fairness_module': 'unfair'
    },
    'name': 'German_Male',
    'hyper_paramaters': {
        'ruleComplexity': [17]
    }
}]
results = run_test(test_params, globalArgs, dataInfo, verbose = False)
# Out:
# {'data': 'data/german_male.csv', 'price_limit': 45, 'train_limit': 300, 'fixed_model_params': {'ruleGenerator': 'DNF_IP', 'numRulesToReturn': 100, 'fairness_module': 'unfair'}, 'name': 'German_Male', 'hyper_paramaters': {'ruleComplexity': [17]}}
# 1 parameters provided for hyper-parameter ruleComplexity
# ****** Running split 0 ******
# **** Running Test German_Male ****
# Split 0
# unfair
# Using DNF_IP
# Using license file /Users/connorlawless/gurobi.lic
# Academic license - for non-commercial use only
# Time limit for column generation exceeded. Solving MIP.
# Results: (Acc) 0.659 (Time) 302 (Complex) 12 (Cols Gen) 71  (Num Iter) 9
# ...

# %%
dataInfo = {
    'file': 'data/german_female.csv',
    'groupCol': 'gender'
}

globalArgs = {
    'num_splits': 5,
}

test_params = [{
    'data': 'data/german_female.csv',
    'price_limit': 45,
    'train_limit': 300,
    'fixed_model_params': {
        'ruleGenerator': 'DNF_IP',
        'numRulesToReturn': 100,
        'fairness_module': 'unfair'
    },
    'name': 'German_Female',
    'hyper_paramaters': {
        'ruleComplexity': [17]
    }
}]
results = run_test(test_params, globalArgs, dataInfo, verbose = False)
# Out:
# {'data': 'data/german_female.csv', 'price_limit': 45, 'train_limit': 300, 'fixed_model_params': {'ruleGenerator': 'DNF_IP', 'numRulesToReturn': 100, 'fairness_module': 'unfair'}, 'name': 'German_Female', 'hyper_paramaters': {'ruleComplexity': [17]}}
# 1 parameters provided for hyper-parameter ruleComplexity
# ****** Running split 0 ******
# **** Running Test German_Female ****
# Split 0
# unfair
# Using DNF_IP
# Using license file /Users/connorlawless/gurobi.lic
# Academic license - for non-commercial use only
# Time limit for column generation exceeded. Solving MIP.
# Results: (Acc) 0.603 (Time) 305 (Complex) 16 (Cols Gen) 68  (Num Iter) 8
# ...
