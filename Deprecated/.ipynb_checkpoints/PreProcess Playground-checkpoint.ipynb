# %%
import pandas as pd
import numpy as np
import warnings
from binerizer import *

# %%
credit = pd.read_csv('data/credit.csv')
credit
# Out:
#     X1     X2      X3 X4 X5  X6  X7    X8     X9    X10  X11    X12 X13  X14  \
# 0    b  30.83   0.000  u  g   w   v  1.25  False  False    1  False   g  202
# 1    a  58.67   4.460  u  g   q   h  3.04  False  False    6  False   g   43
# 2    a  24.50   0.500  u  g   q   h  1.50  False  False    0  False   g  280
# 3    b  27.83   1.540  u  g   w   v  3.75  False  False    5  False   g  100
# 4    b  20.17   5.625  u  g   w   v  1.71  False  False    0  False   s  120
# ..  ..    ...     ... .. ..  ..  ..   ...    ...    ...  ...    ...  ..  ...
# 648  b  21.08  10.085  y  p   e   h  1.25  False  False    0  False   g  260
# 649  a  22.67   0.750  u  g   c   v  2.00  False  False    2  False   g  200
# 650  a  25.25  13.500  y  p  ff  ff  2.00  False  False    1  False   g  200
# 651  b  17.92   0.205  u  g  aa   v  0.04  False  False    0  False   g  280
# 652  b  35.00   3.375  u  g   c   h  8.29  False  False    0  False   g    0
#
#      X15      Y
# 0      0   True
# ...

# %%
binerizeData(credit, verbose = True)
# Out:
# Column X1: Applying 1 Hot Encoding.
# Column X2: Binarzing with specified numeric strategy.
# Column X3: Binarzing with specified numeric strategy.
# Column X4: Applying 1 Hot Encoding.
# Column X5: Applying 1 Hot Encoding.
# Column X6: Applying 1 Hot Encoding.
# Column X7: Applying 1 Hot Encoding.
# Column X8: Binarzing with specified numeric strategy.
# Column X9: Copying to final dataframe.
# Column X10: Copying to final dataframe.
# Column X11: Binarzing with specified numeric strategy.
# Column X12: Copying to final dataframe.
# Column X13: Applying 1 Hot Encoding.
# Column X14: Binarzing with specified numeric strategy.
# Column X15: Binarzing with specified numeric strategy.
# Column Y: Copying to final dataframe.
#       X1_a   X1_b   X1_a   X1_b  X2_19.17*  X2_21.53*  X2_23.25*  X2_25.42*  \
# 0    False   True   True  False      False      False      False      False
# 1     True  False  False   True      False      False      False      False
# ...
